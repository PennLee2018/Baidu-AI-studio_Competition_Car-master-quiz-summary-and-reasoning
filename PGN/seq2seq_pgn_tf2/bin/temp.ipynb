# %%
import pandas as pd
test_df = pd.read_csv('E:/hello.csv')
print(test_df)
# Out:
#     QID                                         Prediction
# 0    Q1  ，，，，的，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，...
# 1    Q2  的，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，...
# 2    Q3  的，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，...
# 3    Q4  的，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，...
# 4    Q5  的，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，...
# 5    Q6  ，，，，的，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，...
# 6    Q7  ，，，，的，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，...
# 7    Q8  ，，，，的，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，...
# 8    Q9  的，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，...
# 9   Q10  的，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，...
# 10  Q11  ，，，，的，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，...
# 11  Q12  的，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，...
# 12  Q13  ，，，，的，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，...
# 13  Q14  的，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，...
# 14  Q15  的，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，，...
# ...

# %%
    results  = ['的，，，，，，，，，，，，，，','，，，的，']
    name=['one']
    r_save=pd.DataFrame(columns=['p'],data=results)
    r_save.to_csv("result_save_path.csv", index=None, sep=',')
